# %% [markdown]
# # Notebook: SvaraAI Reply Classifier
#
# This notebook outlines the steps. Run the provided Python modules in src/ to execute training locally.

# %% [markdown]
# - Load dataset
# - Preprocess
# - Train baseline
# - Evaluate
# - (Optional) Fine-tune transformer
# - Test API
